# %% [markdown]
# #  Python 及其数学基础

# %% [markdown]
# ## 主要内容

# %% [markdown]
# * 机器学习、深度学习与本课程示例概述
# * 机器学习的角度看数学
#     * 数学分析
#         * 导数与梯度
#         * Taylor展开的应用
#     * 概率论基础
#         * 古典概型
#         * 频率学派和贝叶斯学派
#         * 常见的概率分布
#         * Sigmoid/Logistic函数的引入
# * Python基础

# %% [markdown]
# ## 人类的阅读

# %% [markdown]
# * 有监督学习 : 存在标记, 通过将预测和标记之间的偏差进行度量评估来实现学习
# * 无监督学习 : 不存在标记, 通过一定的规则偏好进行学习
# * 增强学习 : 滞后性的有监督学习

# %% [markdown]
# ## 机器学习的内涵和外延

# %% [markdown]
# * 机器学习可以解决什么
#     * 给定数据的预测问题
#         * 数据清洗/特征选择
#         * 确定算法模型/参数优化
#         * 结果预测

# %% [markdown]
# ## Python Code sample1

# %%
import math
import matplotlib.pyplot as plt

# %%
x = [float(i)/100.0 for i in range(1, 300)]
y = [math.log(i) for i in x]
plt.plot(x, y, 'r-', linewidth=3, label='log Curve')
a = [x[20], x[175]]
b = [y[20], y[175]]
plt.plot(a, b, 'g-', linewidth=2)
plt.plot(a, b, 'b*', markersize=15, alpha=0.75)
plt.legend(loc='upper left')
plt.grid(True)
plt.xlabel('X')
plt.ylabel('log(X)')
plt.show()

# %% [markdown]
# ## Taylar公式

# %% [markdown]
# $ f(x) = $
