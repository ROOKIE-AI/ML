# %% [markdown]
# # House Prices - Advanced Regression Techniques

# %% [markdown]
# ## Introduce

# %% [markdown]
# | **字段名**           | **解释**                                                                 |
# |----------------------|--------------------------------------------------------------------------|
# | Id                   | 每条记录的唯一标识符                                                     |
# | MSSubClass           | 建筑等级或房屋类型的编号                                                 |
# | MSZoning             | 房屋所在的分区类型                                                       |
# | LotFrontage          | 房屋前的街道长度（英尺）                                                 |
# | LotArea              | 房屋所在的地块面积（平方英尺）                                           |
# | Street               | 房屋所在街道的类型                                                       |
# | Alley                | 背街或小巷类型                                                           |
# | LotShape             | 地块形状                                                                 |
# | LandContour          | 地块的平整度                                                             |
# | Utilities            | 房屋可用的公共设施                                                       |
# | LotConfig            | 房屋的配置方式                                                           |
# | LandSlope            | 地块的坡度                                                               |
# | Neighborhood         | 房屋所在的社区或区域名称                                                 |
# | Condition1           | 房屋靠近的主要环境或条件                                                 |
# | Condition2           | 第二个靠近的主要环境或条件                                               |
# | BldgType             | 房屋类型                                                                 |
# | HouseStyle           | 房屋的建筑风格                                                           |
# | OverallQual          | 房屋整体材质和装修的质量                                                 |
# | OverallCond          | 房屋的整体状态                                                           |
# | YearBuilt            | 房屋的建造年份                                                           |
# | YearRemodAdd         | 房屋最近一次翻新或扩建的年份                                             |
# | RoofStyle            | 屋顶的样式                                                               |
# | RoofMatl             | 屋顶材料                                                                 |
# | Exterior1st          | 房屋外墙材料的主要类型                                                   |
# | Exterior2nd          | 房屋外墙材料的次要类型                                                   |
# | MasVnrType           | 外墙装饰的材料类型                                                       |
# | MasVnrArea           | 外墙装饰的面积（平方英尺）                                               |
# | ExterQual            | 外墙材质的质量                                                           |
# | ExterCond            | 外墙材质的整体状态                                                       |
# | Foundation           | 房屋地基的类型                                                           |
# | BsmtQual             | 地下室的高度和质量                                                       |
# | BsmtCond             | 地下室的整体状态                                                         |
# | BsmtExposure         | 地下室外墙是否有窗户                                                     |
# | BsmtFinType1         | 地下室完成的类型                                                         |
# | BsmtFinSF1           | 地下室第一部分的完成面积                                                 |
# | BsmtFinType2         | 地下室第二部分的完成类型                                                 |
# | BsmtFinSF2           | 地下室第二部分的完成面积                                                 |
# | BsmtUnfSF            | 地下室未完成的面积                                                       |
# | TotalBsmtSF          | 地下室总面积                                                             |
# | Heating              | 供暖类型                                                                 |
# | HeatingQC            | 供暖的质量和状态                                                         |
# | CentralAir           | 是否有中央空调                                                           |
# | Electrical           | 房屋的电气系统类型                                                       |
# | 1stFlrSF             | 第一层楼的面积                                                           |
# | 2ndFlrSF             | 第二层楼的面积                                                           |
# | LowQualFinSF         | 低质量完成面积                                                           |
# | GrLivArea            | 地上房屋的总生活面积                                                     |
# | BsmtFullBath         | 地下室的完整浴室数量                                                     |
# | BsmtHalfBath         | 地下室的半浴室数量                                                       |
# | FullBath             | 地上完整浴室数量                                                         |
# | HalfBath             | 地上半浴室数量                                                           |
# | BedroomAbvGr         | 地上卧室数量                                                             |
# | KitchenAbvGr         | 地上厨房数量                                                             |
# | KitchenQual          | 厨房的质量                                                               |
# | TotRmsAbvGrd         | 地上总房间数量                                                           |
# | Functional           | 房屋功能性评分                                                           |
# | Fireplaces           | 壁炉数量                                                                 |
# | FireplaceQu          | 壁炉质量                                                                 |
# | GarageType           | 车库类型                                                                 |
# | GarageYrBlt          | 车库建造年份                                                             |
# | GarageFinish         | 车库内部装修类型                                                         |
# | GarageCars           | 车库容纳车辆的数量                                                       |
# | GarageArea           | 车库面积                                                                 |
# | GarageQual           | 车库质量                                                                 |
# | GarageCond           | 车库状态                                                                 |
# | PavedDrive           | 是否有铺砌的车道                                                         |
# | WoodDeckSF           | 木质露台面积                                                             |
# | OpenPorchSF          | 开放式门廊面积                                                           |
# | EnclosedPorch        | 封闭式门廊面积                                                           |
# | 3SsnPorch            | 三季门廊面积                                                             |
# | ScreenPorch          | 屏幕门廊面积                                                             |
# | PoolArea             | 游泳池面积                                                               |
# | PoolQC               | 游泳池质量                                                               |
# | Fence                | 围栏质量                                                                 |
# | MiscFeature          | 其他不常见的附加功能                                                     |
# | MiscVal              | 其他附加功能的价值                                                       |
# | MoSold               | 房屋售出的月份                                                           |
# | YrSold               | 房屋售出的年份                                                           |
# | SaleType             | 销售类型                                                                 |
# | SaleCondition        | 销售的状况                                                               |
# | SalePrice            | 房屋的销售价格（目标变量，通常用于回归问题）                             |

# %% [markdown]
# ## Import Library

# %%
import os
from pprint import pprint

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sympy import im
from xgboost import XGBRegressor

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load the DataSet

# %%
if not os.path.exists("./data"):
    # !kaggle competitions download -c house-prices-advanced-regression-techniques
    # !mkdir ./data
    # !unzip *.zip -d ./data/
    # !rm -rf *.zip

# %%
train_df = pd.read_csv('./data/train.csv')  # 训练数据
test_df = pd.read_csv('./data/test.csv')    # 测试数据

# %%
print(f"共有{test_df.shape[1]}个特征, {train_df.shape[0]}组训练数据, {test_df.shape[0]}组测试数据")
print(f"{train_df.columns.values}")
# Out:
# 共有80个特征, 1460组训练数据, 1459组测试数据
# ['Id' 'MSSubClass' 'MSZoning' 'LotFrontage' 'LotArea' 'Street' 'Alley'
#  'LotShape' 'LandContour' 'Utilities' 'LotConfig' 'LandSlope'
#  'Neighborhood' 'Condition1' 'Condition2' 'BldgType' 'HouseStyle'
#  'OverallQual' 'OverallCond' 'YearBuilt' 'YearRemodAdd' 'RoofStyle'
#  'RoofMatl' 'Exterior1st' 'Exterior2nd' 'MasVnrType' 'MasVnrArea'
#  'ExterQual' 'ExterCond' 'Foundation' 'BsmtQual' 'BsmtCond' 'BsmtExposure'
#  'BsmtFinType1' 'BsmtFinSF1' 'BsmtFinType2' 'BsmtFinSF2' 'BsmtUnfSF'
#  'TotalBsmtSF' 'Heating' 'HeatingQC' 'CentralAir' 'Electrical' '1stFlrSF'
#  '2ndFlrSF' 'LowQualFinSF' 'GrLivArea' 'BsmtFullBath' 'BsmtHalfBath'
#  'FullBath' 'HalfBath' 'BedroomAbvGr' 'KitchenAbvGr' 'KitchenQual'
#  'TotRmsAbvGrd' 'Functional' 'Fireplaces' 'FireplaceQu' 'GarageType'
#  'GarageYrBlt' 'GarageFinish' 'GarageCars' 'GarageArea' 'GarageQual'
#  'GarageCond' 'PavedDrive' 'WoodDeckSF' 'OpenPorchSF' 'EnclosedPorch'
# ...

# %% [markdown]
# ### Missing situation

# %%
train_df.isnull().sum().loc[lambda x: x > 0].sort_values(ascending=False) / train_df.shape[0] * 100
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# MasVnrType      59.726027
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtCond         2.534247
# BsmtQual         2.534247
# MasVnrArea       0.547945
# Electrical       0.068493
# dtype: float64

# %%
test_df.isnull().sum().loc[lambda x: x > 0].sort_values(ascending=False) / test_df.shape[0] * 100
# Out:
# PoolQC          99.794380
# MiscFeature     96.504455
# Alley           92.666210
# Fence           80.123372
# MasVnrType      61.274846
# FireplaceQu     50.034270
# LotFrontage     15.558602
# GarageCond       5.346127
# GarageYrBlt      5.346127
# GarageQual       5.346127
# GarageFinish     5.346127
# GarageType       5.209047
# BsmtCond         3.084304
# BsmtExposure     3.015764
# BsmtQual         3.015764
# BsmtFinType1     2.878684
# BsmtFinType2     2.878684
# MasVnrArea       1.028101
# MSZoning         0.274160
# BsmtFullBath     0.137080
# BsmtHalfBath     0.137080
# Functional       0.137080
# Utilities        0.137080
# GarageCars       0.068540
# GarageArea       0.068540
# TotalBsmtSF      0.068540
# KitchenQual      0.068540
# BsmtUnfSF        0.068540
# BsmtFinSF2       0.068540
# BsmtFinSF1       0.068540
# Exterior2nd      0.068540
# Exterior1st      0.068540
# SaleType         0.068540
# dtype: float64

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### 1. 不同类型指标的房屋均价

# %%
# 选择多个分类标准
categories = train_df.columns[(train_df.dtypes == np.dtype(np.object_)).values]  # type: ignore

# %%
# 创建一个图形对象和子图网格
fig, axes = plt.subplots(nrows=11, ncols=4, figsize=(20, 40))

# 遍历每个分类标准
for i, (category, ax) in enumerate(zip(categories, axes.reshape(-1))):
    # 按分类标准进行分组并计算均价
    group_df = train_df.groupby(by=category).agg(mean_saleprice=('SalePrice', 'mean'))
    
    # 绘制条形图
    ax.bar(group_df.index.astype(str), group_df['mean_saleprice'], color='skyblue')
    
    # 设置图表信息
    ax.set_title(f'Mean SalePrice by {category}')
    ax.set_xlabel(category)
    ax.set_ylabel('Mean SalePrice')
    ax.tick_params(axis='x', rotation=45)  # x 轴标签旋转以避免重叠

# 自动调整子图布局
plt.tight_layout()
plt.show()

# %%
# 创建一个图形对象和子图网格
fig, axes = plt.subplots(nrows=11, ncols=4, figsize=(20, 40))

# 遍历每个分类标准
for i, (category, ax) in enumerate(zip(categories, axes.reshape(-1))):
    sns.boxplot(x=category, y='SalePrice', data=train_df, ax=ax)
    ax.set_title('Price Distribution by Fence Type')
    ax.tick_params(axis='x', rotation=45)  # x 轴标签旋转以避免重叠
    # plt.show()
# 自动调整子图布局
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. 不同数量指标下的房屋均价

# %%
# 选择多个分类标准
categories = [name for name, t  in zip(train_df.columns, train_df.dtypes) if t is np.dtype(np.int64)]
# 创建一个图形对象和子图网格
fig, axes = plt.subplots(ncols=3, nrows=12, figsize=(20, 40))

# 遍历每个分类标准
for i, (category, ax) in enumerate(zip(categories, axes.reshape(-1))):
    # 按分类标准进行分组并计算均价
    group_df = train_df.groupby(by=category).agg(mean_saleprice=('SalePrice', 'mean'))
    
    # 绘制条形图
    ax.bar(group_df.index, group_df['mean_saleprice'], color='skyblue')
    
    # 设置图表信息
    ax.set_title(f'Mean SalePrice by {category}')
    ax.set_xlabel(category)
    ax.set_ylabel('Mean SalePrice')
    ax.tick_params(axis='x', rotation=45)  # x 轴标签旋转以避免重叠

# 自动调整子图布局
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. 不同连续指标的相关性分析

# %%
featue_float = [name for name, t  in zip(train_df.columns, train_df.dtypes) if t is np.dtype(np.float64)]
featue_int = [name for name, t  in zip(train_df.columns, train_df.dtypes) if t is np.dtype(np.int64)]

# %%
len(featue_int), len(featue_float)
# Out:
# (35, 3)

# %%
fig, axes = plt.subplots(ncols=4, nrows=9, figsize=(20, 40))

for featue, ax in zip(featue_int, axes.reshape(-1)):
    ax.scatter(train_df[featue].values, train_df['SalePrice'].values)
    # ax.set_xlabel(featue)
    ax.set_title(featue)
    ax.set_ylabel('SalePrice')

# %%
fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(20, 5))

for featue, ax in zip(featue_float, axes.reshape(-1)):
    ax.scatter(train_df[featue].values, train_df['SalePrice'].values)
    # ax.set_xlabel(featue)
    ax.set_title(featue)
    ax.set_ylabel('SalePrice')

# %%
correlation_matrix = train_df[featue_float + featue_int].corr()

# %%
correlation_matrix['SalePrice'].abs().sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# KitchenAbvGr     0.135907
# EnclosedPorch    0.128578
# ScreenPorch      0.111447
# PoolArea         0.092404
# MSSubClass       0.084284
# OverallCond      0.077856
# MoSold           0.046432
# 3SsnPorch        0.044584
# YrSold           0.028923
# LowQualFinSF     0.025606
# Id               0.021917
# ...

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### 1. one-hat

# %%
df = pd.concat([train_df, test_df])
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
one_hat_featue_names = df.columns[(df.dtypes == np.dtype(np.object_)).values] # type: ignore
for name in one_hat_featue_names:
    categories = df[name].unique()
    if categories.shape[0] == 2:
        df[name] = df[name].map({k: i for i, k in enumerate(categories)})
    elif categories.shape[0] == 1:
        df.drop(name, axis=1)
    else:
        df = pd.get_dummies(df, columns=[name], prefix=name)

# %%
df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  Street  OverallQual  OverallCond  \
# 0   1          60         65.0     8450       0            7            5
# 1   2          20         80.0     9600       0            6            8
# 2   3          60         68.0    11250       0            7            5
# 3   4          70         60.0     9550       0            7            5
# 4   5          60         84.0    14260       0            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ...  SaleType_ConLw  SaleType_New  \
# 0       2003          2003       196.0  ...           False         False
# 1       1976          1976         0.0  ...           False         False
# 2       2001          2002       162.0  ...           False         False
# 3       1915          1970         0.0  ...           False         False
# 4       2000          2000       350.0  ...           False         False
#
# ...

# %%
pprint(df.columns.values)
# Out:
# array(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'Street',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'CentralAir', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch',
#        '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold',
#        'YrSold', 'SalePrice', 'MSZoning_C (all)', 'MSZoning_FV',
#        'MSZoning_RH', 'MSZoning_RL', 'MSZoning_RM', 'Alley_Grvl',
#        'Alley_Pave', 'LotShape_IR1', 'LotShape_IR2', 'LotShape_IR3',
#        'LotShape_Reg', 'LandContour_Bnk', 'LandContour_HLS',
#        'LandContour_Low', 'LandContour_Lvl', 'Utilities_AllPub',
# ...

# %% [markdown]
# ### 2. Missing value handling

# %%
missing_rate = df.isnull().mean().loc[lambda x: x > 0] * 100
missing_rate
# Out:
# LotFrontage     16.649538
# MasVnrArea       0.787941
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# GarageYrBlt      5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# SalePrice       49.982871
# dtype: float64

# %%
# 直接剔除缺失比例超过60%的因子
train_df.drop(list(missing_rate[missing_rate > 60].index.values), axis=1, inplace=True)

# %%
# 对缺失比例低于60%的因子选择用中位数替代
for name in missing_rate[missing_rate < 60].index.values:
    if name == 'SalePrice':
        continue
    df[name].fillna(df[name].median(), inplace=True)

# %%
df.isnull().mean().loc[lambda x:  x > 0]
# Out:
# SalePrice    0.499829
# dtype: float64

# %%
df.shape
# Out:
# (2919, 287)

# %% [markdown]
# ### 3. feature scaling

# %%
_X_train, _y_train = df[df['Id'].isin(train_df['Id'])].drop('SalePrice', axis=1).values, df[df['Id'].isin(train_df['Id'])]['SalePrice'].values.reshape(-1, 1)
X_test = df[df['Id'].isin(test_df['Id'])].drop('SalePrice', axis=1).values

# %%
_y_train.min()
# Out:
# 34900.0

# %%
_X_train.shape, _y_train.shape, X_test.shape
# Out:
# ((1460, 286), (1460, 1), (1459, 286))

# %%
scaler_X = MinMaxScaler()
scaler_y = StandardScaler()
X_train_scaler = scaler_X.fit_transform(_X_train)
X_test_scaler = scaler_X.transform(X_test)
y_train_scaler = scaler_y.fit_transform(_y_train)

# %% [markdown]
# ## Modeling

# %%
X_train, X_valid, y_train, y_vaild = train_test_split(X_train_scaler, y_train_scaler, test_size=0.1, random_state=42)
y_vaild = scaler_y.inverse_transform(y_vaild)

# %%
y_vaild.min()
# Out:
# 35311.0

# %%
models = {
    'LR': LinearRegression(),
    'RF': RandomForestRegressor(n_estimators=100),
    'XGB': XGBRegressor(),
    'MLP': MLPRegressor(hidden_layer_sizes=(400, 100, 10), max_iter=300)
}

# %%
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = scaler_y.inverse_transform(model.predict(X_valid))
    y_pred = np.where(y_pred <= 0, y_vaild.min(), y_pred) # type: ignore
    msle = mean_squared_log_error(y_pred, y_vaild)
    print(f"{model_name}: {msle:.4f}")
# Out:
# LR: 0.0683
# RF: 0.0183
# XGB: 0.0145
# MLP: 0.0211

# %% [markdown]
# ## Submit

# %%
y_test_pred_scaler = models['XGB'].predict(X_test_scaler)
y_test_pred = scaler_y.inverse_transform(y_test_pred_scaler)
y_test_pred.shape
# Out:
# (1459,)

# %%
output = pd.DataFrame({'Id': test_df.Id, 'SalePrice': y_test_pred})
output.to_csv('./data/submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
# !kaggle competitions submit -c house-prices-advanced-regression-techniques -f ./data/submission.csv -m "XGB,直接处理, 不做特征工程"
# Out:
# ...
# 100%|██████████████████████████████████████| 21.2k/21.2k [00:01<00:00, 20.6kB/s]
# Successfully submitted to House Prices - Advanced Regression Techniques
